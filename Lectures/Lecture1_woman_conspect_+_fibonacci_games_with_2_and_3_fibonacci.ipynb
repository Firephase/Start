# %%
def do_it_better(func):
  def wrapper(param1=0,param2=0):
      for i in range(10):
        func(param1,param2)
        print()
  return wrapper

# %%
@do_it_better
def message(param1=0,param2=0):
    print('I am  here')

message()
@do_it_better
def merge(word1,word2):
  print(word1+word2)
merge('alef', 'beit')
print('as;dfhys')
merge('alef','beit')
# Out:
# I am  here
#
# I am  here
#
# I am  here
#
# I am  here
#
# I am  here
#
# I am  here
#
# I am  here
#
# I am  here
#
# I am  here
#
# I am  here
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# as;dfhys
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit
#
# alefbeit

# %%
@do_it_better
def my_func(param1,param2=0):
    print(param1)
my_func('I am writing something')
# Out:
# I am writing something
#
# I am writing something
#
# I am writing something
#
# I am writing something
#
# I am writing something
#
# I am writing something
#
# I am writing something
#
# I am writing something
#
# I am writing something
#
# I am writing something

# %%
def decorator_constructor(dec_param1,dec_param2):
  print("I am a dec maker \n", "external params are:", dec_param1, "and",dec_param2,"\n")
  def decorator(func):
      print("I am an internal dec \n")
      def wrapper(func_arg1,func_arg2):

        print("ext params are ::::::: ", dec_param1, dec_param2)
        print("func params are", func_arg1,'and ', func_arg2)
        func(func_arg1,func_arg2)
      return wrapper
  return decorator

# %%
@decorator_constructor('Ext1','Ext2')
def test_fun(arg1,arg2):
    print('internal function params are:', arg1, 'and', arg2, "\n")

test_fun('goal', 'love')


@decorator_constructor('Ext3','Ext4')
def test_fun(arg1,arg2):
    print('internal function params are:', arg1, 'and', arg2, "\n")

test_fun('goal', 'love')


test_fun('a','b')
# Out:
# I am a dec maker
#  external params are: Ext1 and Ext2
#
# I am an internal dec
#
# ext params are :::::::  Ext1 Ext2
# func params are goal and  love
# internal function params are: goal and love
#
# I am a dec maker
#  external params are: Ext3 and Ext4
#
# I am an internal dec
#
# ext params are :::::::  Ext3 Ext4
# func params are goal and  love
# internal function params are: goal and love
#
# ext params are :::::::  Ext3 Ext4
# func params are a and  b
# internal function params are: a and b

# %%
class Cat:
    def __init__(self, name='', age=0):
        self.name = name
        self.age = age
    def __add__(self,other):
        return Cat(self.name+ "+" + other.name,self.age+other.age)
    def __repr__(self):
      return f"Cat({self.name},{self.age})"
    def __call__(self): #call an object as a function
        print("ХУЙ")

# %%
cat1 = Cat('Max',2)
cat2 = Cat('Bantiec',1)
cat3 = cat1+cat2
print(cat3.name,cat3.age)
cat1()
# Out:
# Max+Bantiec 3
# ХУЙ

# %%
dir()
a = 13
dir()
# Out:
# ['Cat',
#  'In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'cat1',
#  'cat2',
#  'cat3',
#  'decorator_constructor',
#  'do_it_better',
#  'exit',
#  'get_ipython',
#  'merge',
#  'message',
#  'my_func',
#  'quit',
#  'test_fun']

# %%
del a
dir()
# Out:
# ['Cat',
#  'In',
#  'Out',
#  '_',
#  '_8',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'cat1',
#  'cat2',
#  'cat3',
#  'decorator_constructor',
#  'do_it_better',
#  'exit',
#  'get_ipython',
#  'merge',
#  'message',
#  'my_func',
#  'quit',
#  'test_fun']

# %%
del _1
dir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-99d107408bd3> in <cell line: 1>()
# ----> 1 del _1
#       2 dir()
#
# NameError: name '_1' is not defined

# %%
del _4
dir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-94795cfd957f> in <cell line: 1>()
# ----> 1 del _4
#       2 dir()
#
# NameError: name '_4' is not defined

# %%
_i3
_5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1b6e219d454d> in <cell line: 2>()
#       1 _i3
# ----> 2 _5
#
# NameError: name '_5' is not defined

# %%
_iii
_oh
# Out:
# {8: ['Cat',
#   'In',
#   'Out',
#   '_',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'a',
#   'cat1',
#   'cat2',
#   'cat3',
#   'decorator_constructor',
#   'do_it_better',
#   'exit',
#   'get_ipython',
#   'merge',
#   'message',
#   'my_func',
#   'quit',
#   'test_fun'],
#  9: ['Cat',
#   'In',
#   'Out',
#   '_',
#   '_8',
#   '__',
#   '___',
#   '__builtin__',
#   '__builtins__',
#   '__doc__',
#   '__loader__',
#   '__name__',
#   '__package__',
#   '__spec__',
#   '_dh',
#   '_i',
#   '_i1',
#   '_i2',
#   '_i3',
#   '_i4',
#   '_i5',
#   '_i6',
#   '_i7',
#   '_i8',
#   '_i9',
#   '_ih',
#   '_ii',
#   '_iii',
#   '_oh',
#   'cat1',
#   'cat2',
#   'cat3',
#   'decorator_constructor',
#   'do_it_better',
#   'exit',
#   'get_ipython',
#   'merge',
#   'message',
#   'my_func',
#   'quit',
#   'test_fun']}

# %%
help(_oh)
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Built-in subclasses:
#  |      StgDict
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __ior__(self, value, /)
#  |      Return self|=value.
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __or__(self, value, /)
#  |      Return self|value.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __reversed__(self, /)
#  |      Return a reverse iterator over the dict keys.
#  |
#  |  __ror__(self, value, /)
#  |      Return value|self.
#  |
#  |  __setitem__(self, key, value, /)
#  |      Set self[key] to value.
#  |
#  |  __sizeof__(...)
#  |      D.__sizeof__() -> size of D in memory, in bytes
#  |
#  |  clear(...)
#  |      D.clear() -> None.  Remove all items from D.
#  |
#  |  copy(...)
#  |      D.copy() -> a shallow copy of D
#  |
#  |  get(self, key, default=None, /)
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  items(...)
#  |      D.items() -> a set-like object providing a view on D's items
#  |
#  |  keys(...)
#  |      D.keys() -> a set-like object providing a view on D's keys
#  |
#  |  pop(...)
#  |      D.pop(k[,d]) -> v, remove specified key and return the corresponding value.
#  |
#  |      If the key is not found, return the default if given; otherwise,
#  |      raise a KeyError.
#  |
#  |  popitem(self, /)
#  |      Remove and return a (key, value) pair as a 2-tuple.
#  |
#  |      Pairs are returned in LIFO (last-in, first-out) order.
#  |      Raises KeyError if the dict is empty.
#  |
#  |  setdefault(self, key, default=None, /)
#  |      Insert key with a value of default if key is not in the dictionary.
#  |
#  |      Return the value for key if key is in the dictionary, else default.
#  |
#  |  update(...)
#  |      D.update([E, ]**F) -> None.  Update D from dict/iterable E and F.
#  |      If E is present and has a .keys() method, then does:  for k in E: D[k] = E[k]
#  |      If E is present and lacks a .keys() method, then does:  for k, v in E: D[k] = v
#  |      In either case, this is followed by: for k in F:  D[k] = F[k]
#  |
#  |  values(...)
#  |      D.values() -> an object providing a view on D's values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  __class_getitem__(...) from builtins.type
#  |      See PEP 585
#  |
#  |  fromkeys(iterable, value=None, /) from builtins.type
#  |      Create a new dictionary with keys from iterable and values set to value.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __hash__ = None

# %%
x = 4
id(x)
x = 2*x
id(x)
# Out:
# 134159784526288

# %%
id(x)
# Out:
# 134159784526288

# %%
id(3*x)
# Out:
# 134159784526800

# %%
id(x)
# Out:
# 134159784526288

# %%
id(3*x)
# Out:
# 134159784526800

# %%
id(4*x)
# Out:
# 134159784527056

# %%
for i in range(100):
  print(i, id(i*x), sep = ' and ')
# Out:
# 0 and 134159784526032
# 1 and 134159784526288
# 2 and 134159784526544
# 3 and 134159784526800
# 4 and 134159784527056
# 5 and 134159784527312
# 6 and 134159784527568
# 7 and 134159784527824
# 8 and 134159784528080
# 9 and 134159784528336
# 10 and 134159784528592
# 11 and 134159784528848
# 12 and 134159784529104
# 13 and 134159784529360
# 14 and 134159784529616
# 15 and 134159784529872
# 16 and 134159784530128
# 17 and 134159784530384
# 18 and 134159784530640
# 19 and 134159784530896
# 20 and 134159784531152
# 21 and 134159784531408
# 22 and 134159784531664
# 23 and 134159784531920
# 24 and 134159784532176
# 25 and 134159784532432
# 26 and 134159784532688
# 27 and 134159784532944
# 28 and 134159784533200
# 29 and 134159784533456
# 30 and 134159784533712
# 31 and 134159784533968
# 32 and 134159784534224
# 33 and 134159480374736
# 34 and 134159480374928
# 35 and 134159480374736
# 36 and 134159480374928
# 37 and 134159480374736
# 38 and 134159480374928
# 39 and 134159480374736
# 40 and 134159480374928
# 41 and 134159480374736
# 42 and 134159480374928
# 43 and 134159480374736
# 44 and 134159480374928
# 45 and 134159480374736
# 46 and 134159480374928
# 47 and 134159480374736
# 48 and 134159480374928
# 49 and 134159480374736
# 50 and 134159480374928
# 51 and 134159480374736
# 52 and 134159480374928
# 53 and 134159480374736
# 54 and 134159480374928
# 55 and 134159480374736
# 56 and 134159480374928
# 57 and 134159480374736
# 58 and 134159480374928
# 59 and 134159480374736
# 60 and 134159480374928
# 61 and 134159480374736
# 62 and 134159480374928
# 63 and 134159480374736
# 64 and 134159480374928
# 65 and 134159480374736
# 66 and 134159480374928
# 67 and 134159480374736
# 68 and 134159480374928
# 69 and 134159480374736
# 70 and 134159480374928
# 71 and 134159480374736
# 72 and 134159480374928
# 73 and 134159480374736
# 74 and 134159480374928
# 75 and 134159480374736
# 76 and 134159480374928
# 77 and 134159480374736
# 78 and 134159480374928
# 79 and 134159480374736
# 80 and 134159480374928
# 81 and 134159480374736
# 82 and 134159480374928
# 83 and 134159480374736
# 84 and 134159480374928
# 85 and 134159480374736
# 86 and 134159480374928
# 87 and 134159480374736
# 88 and 134159480374928
# 89 and 134159480374736
# 90 and 134159480374928
# 91 and 134159480374736
# 92 and 134159480374928
# 93 and 134159480374736
# 94 and 134159480374928
# 95 and 134159480374736
# 96 and 134159480374160
# 97 and 134159480374736
# 98 and 134159480374160
# 99 and 134159480374736

# %%
  del 30*x #there is no such an object
# Out:
#   File "<ipython-input-24-a9177d75f932>", line 1
#     del 30*x #there is no such an object
#         ^
# SyntaxError: cannot delete expression

# %%
import numpy as np

#building a function that calculates Pezano period for  F_l = F_l-1 + F_l-2 + .... F_l-deg modulo n
def period(n,deg):
  arr = np.zeros((6*n**(deg-1),deg))
  arr[0][deg-1]=1
  for i in range(deg-2):
    arr[1][i]=0
  arr[1][deg-2],arr[1][deg-1] = 1,1

  s = 2
  #print(arr[0])
  #print(arr[1])
  #print(arr[0],arr[1],sep='\n')
  while not(np.allclose(arr[s-1],arr[0])):

    for i in range(deg-1):
      arr[s][i] = arr[s-1][i+1]

    for i in range(deg):
      arr[s][deg-1] += (arr[s-1][i])
    arr[s][deg-1] = arr[s][deg-1]%n
    #print(arr[s])
    s += 1
  #print(arr,sep='\n')
  #print(s - 1)
  return s - 1


def is_prime(n):
    for i in range(2,n-1):
      if n%i == 0:
        return 0
    return 1

# %%
#Q  = np.ones((3,3))
#Q = 4*Q
#print(np.allclose(Q%4,0))
S = deg(np.ones((3,3)),5)
print(S)

# %%
def np_period(m,n):
  Q = np.zeros((n,n))
  for i in range(n):
    Q[0][i] = 1
  for i in range(1,n):
    Q[i][i-1] = 1
  S = Q
  print(S)
  s = 1
  while not np.allclose(S,np.identity(n)):
    S = S@Q % m
    print(S)
    s += 1
  return s

# %%
#print(np.identity(5))
np_period(5,3)

# %%
import array
#n = int(input())
#for i in range(3,1000):
#  if is_prime(i):
#    print(f'{n} - period for', i, 'is', np_period(i,n))



n = int(input())
x = array.array('f')
y = array.array('f')
for i in range(10,1000):
    if is_prime(i):
      x.append(i)
      y.append(np_period(i,n)/i**n)



#print(x)
#print(y)
print('fib3_period(p)/p^2 ~ ', max(x,y))

plt.plot(x,y)
#plt.ylabel(y)
plt.show()
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#  [ 7.  8.  5.  9.  9.  7.  0.  9.  7.  4.]
#  [ 4.  3.  4.  1.  5.  5.  3.  7.  5.  3.]
#  [ 3.  1.  0.  1.  9.  2.  2.  0.  4.  2.]
#  [ 2.  1. 10.  9. 10.  7.  0.  0.  9.  2.]
#  [ 2.  0. 10.  8.  7.  8.  5.  9.  9.  7.]
#  [ 7.  6.  4.  3.  1.  0.  1.  9.  2.  2.]
#  [ 2.  5.  4.  2.  1. 10.  9. 10.  7.  0.]
#  [ 0.  2.  5.  4.  2.  1. 10.  9. 10.  7.]
#  [ 7.  4.  6.  9.  8.  6.  5.  3.  2.  3.]]
# [[ 5.  9.  9.  7.  0.  9.  7.  4.  0.  4.]
#  [ 4.  1.  5.  5.  3.  7.  5.  3.  0.  7.]
#  [ 7.  8.  5.  9.  9.  7.  0.  9.  7.  4.]
#  [ 4.  3.  4.  1.  5.  5.  3.  7.  5.  3.]
#  [ 3.  1.  0.  1.  9.  2.  2.  0.  4.  2.]
#  [ 2.  1. 10.  9. 10.  7.  0.  0.  9.  2.]
#  [ 2.  0. 10.  8.  7.  8.  5.  9.  9.  7.]
#  [ 7.  6.  4.  3.  1.  0.  1.  9.  2.  2.]
#  [ 2.  5.  4.  2.  1. 10.  9. 10.  7.  0.]
#  [ 0.  2.  5.  4.  2.  1. 10.  9. 10.  7.]]
# [[ 3.  3.  1.  5.  3.  1.  9.  5.  9.  5.]
#  [ 5.  9.  9.  7.  0.  9.  7.  4.  0.  4.]
#  [ 4.  1.  5.  5.  3.  7.  5.  3.  0.  7.]
#  [ 7.  8.  5.  9.  9.  7.  0.  9.  7.  4.]
#  [ 4.  3.  4.  1.  5.  5.  3.  7.  5.  3.]
#  [ 3.  1.  0.  1.  9.  2.  2.  0.  4.  2.]
#  [ 2.  1. 10.  9. 10.  7.  0.  0.  9.  2.]
#  [ 2.  0. 10.  8.  7.  8.  5.  9.  9.  7.]
#  [ 7.  6.  4.  3.  1.  0.  1.  9.  2.  2.]
#  [ 2.  5.  4.  2.  1. 10.  9. 10.  7.  0.]]
# [[ 6.  4.  8.  6.  4.  1.  8.  1.  8.  3.]
#  [ 3.  3.  1.  5.  3.  1.  9.  5.  9.  5.]
#  [ 5.  9.  9.  7.  0.  9.  7.  4.  0.  4.]
#  [ 4.  1.  5.  5.  3.  7.  5.  3.  0.  7.]
#  [ 7.  8.  5.  9.  9.  7.  0.  9.  7.  4.]
#  [ 4.  3.  4.  1.  5.  5.  3.  7.  5.  3.]
#  [ 3.  1.  0.  1.  9.  2.  2.  0.  4.  2.
 2.  1.  3.  2.  5.  7.  6.  1.  6.  2.]
#  [ 2.  0. 10.  1.  0.  3.  5.  4. 10.  4.]
#  [ 4.  9.  7.  6.  8.  7. 10.  1.  0.  6.]
#  [ 6.  9.  3.  1.  0.  2.  1.  4.  6.  5.]
#  [ 5.  1.  4.  9.  7.  6.  8.  7. 10.  1.]
#  [ 1.  4.  0.  3.  8.  6.  5.  7.  6.  9.]
#  [ 9.  3.  6.  2.  5. 10.  8.  7.  9.  8.]]
# [[ 0.  2.  1.  7.  1.  8.  6.  4.  1.  4.]
#  [ 4.  7.  9.  8.  3.  8.  4.  2.  0.  8.]
#  [ 8.  7. 10.  1.  0.  6.  0.  7.  5.  3.]
#  [ 3.  5.  4.  7.  9.  8.  3.  8.  4.  2.]
#  [ 2.  1.  3.  2.  5.  7.  6.  1.  6.  2.]
#  [ 2.  0. 10.  1.  0.  3.  5.  4. 10.  4.]
#  [ 4.  9.  7.  6.  8.  7. 10.  1.  0.  6.]
#  [ 6.  9.  3.  1.  0.  2.  1.  4.  6.  5.]
#  [ 5.  1.  4.  9.  7.  6.  8.  7. 10.  1.]
#  [ 1.  4.  0.  3.  8.  6.  5.  7.  6.  9.]]
# [[ 2.  1.  7.  1.  8.  6.  4.  1.  4.  0.]
#  [ 0.  2.  1.  7.  1.  8.  6.  4.  1.  4.]
#  [ 4.  7.  9.  8.  3.  8.  4.  2.  0.  8.]
#  [ 8.  7. 10.  1.  0.  6.  0.  7.  5.  3.]
#  [ 3.  5.  4.  7.  9.  8.  3.  8.  4.  2.]
#  [ 2.  1.  3.  2.  5.  7.  6.  1.  6.  2.]
#  [ 2.  0. 10.  1.  0.  3.  5.  4. 10.  4.]
#  [ 4.  9.  7.  6.  8.  7. 10.  1.  0.  6.]
#  [ 6.  9.  3.  1.  0.  2.  1.  4.  6.  5.]
#  [ 5.  1.  4.  9.  7.  6.  8.  7. 10.  1.]]
# [[ 3.  9.  3. 10.  8.  6.  3.  6.  2.  2.]
#  [ 2.  1.  7.  1.  8.  6.  4.  1.  4.  0.]
#  [ 0.  2.  1.  7.  1.  8.  6.  4.  1.  4.]
#  [ 4.  7.  9.  8.  3.  8.  4.  2.  0.  8.]
#  [ 8.  7. 10.  1.  0.  6.  0.  7.  5.  3.]
#  [ 3.  5.  4.  7.  9.  8.  3.  8.  4.  2.]
#  [ 2.  1.  3.  2.  5.  7.  6.  1.  6.  2.]
#  [ 2.  0. 10.  1.  0.  3.  5.  4. 10.  4.]
#  [ 4.  9.  7.  6.  8.  7. 10.  1.  0.  6.]
#  [ 6.  9.  3.  1.  0.  2.  1.  4.  6.  5.]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-1318b97dd2fc> in <cell line: 12>()
#      13     if is_prime(i):
#      14       x.append(i)
# ---> 15       y.append(np_period(i,n)/i**n)
#      16
#      17
#
# <ipython-input-28-17c16d0c3796> in np_period(m, n)
#      10   while not np.allclose(S,np.identity(n)):
#      11     S = S@Q % m
# ---> 12     print(S)
#      13     s += 1
#      14   return s
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in write(self, string)
#     400             is_child = (not self._is_master_process())
#     401             # only touch the buffer in the IO thread to avoid races
# --> 402             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403             if is_child:
#     404                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.10/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.10/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
for i in range(2,100):
  if (is_prime(i)):
    print('period for', i,'is',period(i,3))
# Out:
# period for 2 is 4
# period for 3 is 13
# period for 5 is 31
# period for 7 is 48
# period for 11 is 110
# period for 13 is 168
# period for 17 is 96
# period for 19 is 360
# period for 23 is 553
# period for 29 is 140
# period for 31 is 331
# period for 37 is 469
# period for 41 is 560
# period for 43 is 308
# period for 47 is 46
# period for 53 is 52
# period for 59 is 3541
# period for 61 is 1860
# period for 67 is 1519
# period for 71 is 5113
# period for 73 is 5328
# period for 79 is 3120
# period for 83 is 287
# period for 89 is 8011
# period for 97 is 3169

# %%
for i in range(100,1000):
  if is_prime(i):
    print('hypo : period(i,3)/i**2+i+1= ', period(i,3)/(i**2+i+1), 'for ', i)
# Out:
# hypo : period(i,3)/i**2+i+1=  0.06600019411821799 for  101
# hypo : period(i,3)/i**2+i+1=  0.004760571268552226 for  103
# hypo : period(i,3)/i**2+i+1=  0.11006316518127542 for  107
# hypo : period(i,3)/i**2+i+1=  0.08256192144108081 for  109
# hypo : period(i,3)/i**2+i+1=  1.0 for  113
# hypo : period(i,3)/i**2+i+1=  0.33068831887802175 for  127
# hypo : period(i,3)/i**2+i+1=  0.33076967559127973 for  131
# hypo : period(i,3)/i**2+i+1=  1.0 for  137
# hypo : period(i,3)/i**2+i+1=  0.19855094804994605 for  139
# hypo : period(i,3)/i**2+i+1=  0.3310813833832938 for  149
# hypo : period(i,3)/i**2+i+1=  0.12416677558489086 for  151
# hypo : period(i,3)/i**2+i+1=  0.3333333333333333 for  157
# hypo : period(i,3)/i**2+i+1=  0.006059925934238581 for  163
# hypo : period(i,3)/i**2+i+1=  0.33132551591403214 for  167
# hypo : period(i,3)/i**2+i+1=  0.08284888549314022 for  173
# hypo : period(i,3)/i**2+i+1=  1.0 for  179
# hypo : period(i,3)/i**2+i+1=  0.3333333333333333 for  181
# hypo : period(i,3)/i**2+i+1=  1.0 for  191
# hypo : period(i,3)/i**2+i+1=  0.12434901049595384 for  193
# hypo : period(i,3)/i**2+i+1=  0.08290819596482682 for  197
# hypo : period(i,3)/i**2+i+1=  0.004974749378156328 for  199
# hypo : period(i,3)/i**2+i+1=  0.12440480182415667 for  211
# hypo : period(i,3)/i**2+i+1=  0.3333333333333333 for  223
# hypo : period(i,3)/i**2+i+1=  0.3318584925710532 for  227
# hypo : period(i,3)/i**2+i+1=  0.3333333333333333 for  229
# hypo : period(i,3)/i**2+i+1=  0.16594831538983548 for  233
# hypo : period(i,3)/i**2+i+1=  0.0829832115897561 for  239
# hypo : period(i,3)/i**2+i+1=  0.49791677382850674 for  241
# hypo : period(i,3)/i**2+i+1=  1.0 for  251
# hypo : period(i,3)/i**2+i+1=  0.0038608291733904414 for  257
# hypo : period(i,3)/i**2+i+1=  0.33206112367318136 for  263
# hypo : period(i,3)/i**2+i+1=  0.0036898844845864713 for  269
# hypo : period(i,3)/i**2+i+1=  0.9962964470310529 for  271
# hypo : period(i,3)/i**2+i+1=  0.16606282545742596 for  277
# hypo : period(i,3)/i**2+i+1=  0.1660714511060914 for  281
# hypo : period(i,3)/i**2+i+1=  0.1660756721784679 for  283
# hypo : period(i,3)/i**2+i+1=  0.332191820577412 for  293
# hypo : period(i,3)/i**2+i+1=  0.3322440432754846 for  307
# hypo : period(i,3)/i**2+i+1=  0.0031947894015438047 for  311
# hypo : period(i,3)/i**2+i+1=  0.3333333333333333 for  313
# hypo : period(i,3)/i**2+i+1=  1.0 for  317
# hypo : period(i,3)/i**2+i+1=  0.3333333333333333 for  331
# hypo : period(i,3)/i**2+i+1=  0.1424319839869367 for  337
# hypo : period(i,3)/i**2+i+1=  0.3323699661303278 for  347
# hypo : period(i,3)/i**2+i+1=  0.14244664390795 for  349
# hypo : period(i,3)/i**2+i+1=  1.0 for  353
# hypo : period(i,3)/i**2+i+1=  0.3324022562499516 for  359
# hypo : period(i,3)/i**2+i+1=  0.3333333333333333 for  367
# hypo : period(i,3)/i**2+i+1=  0.9973118857658975 for  373
# hypo : period(i,3)/i**2+i+1=  0.3333333333333333 for  379
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-397469906689> in <cell line: 1>()
#       1 for i in range(100,1000):
#       2   if is_prime(i):
# ----> 3     print('hypo : period(i,3)/i**2+i+1= ', period(i,3)/(i**2+i+1), 'for ', i)
#
# <ipython-input-25-cc038faadd3c> in period(n, deg)
#      13   #print(arr[1])
#      14   #print(arr[0],arr[1],sep='\n')
# ---> 15   while not(np.allclose(arr[s-1],arr[0])):
#      16
#      17     for i in range(deg-1):
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in allclose(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/numeric.py in allclose(a, b, rtol, atol, equal_nan)
#    2263
#    2264     """
# -> 2265     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#    2266     return bool(res)
#    2267
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in isclose(*args, **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/numeric.py in isclose(a, b, rtol, atol, equal_nan)
#    2367     #       Although, the default tolerances are unlikely to be useful
#    2368     if y.dtype.kind != "m":
# -> 2369         dt = multiarray.result_type(y, 1.)
#    2370         y = asanyarray(y, dtype=dt)
#    2371
#
# /usr/local/lib/python3.10/dist-packages/numpy/core/overrides.py in result_type(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
for i in range(3,100):
  if is_prime(i):
    print('hypo : period(i,5)/i**4+i**3+i**2+i+1 = ', period(i,5)/(i**4+i**3+i**2+i+1), 'for ', i)

# %%
for i in range(3,100):
  if is_prime(i):
    print('hypo : period(i,4)/2(i**3+i**2+i+1) = ', period(i,4)/2/(i**3+i**2+i+1), 'for ', i)

# %%
for j in range(2,40):
    if(is_prime(j)):
      for i in range(1,4):
        print('period for', j**i,'is',period(j**i))

# %%
import matplotlib.pyplot as plt
import array

# %%
def max(x,y,n):
    s = 0
    for i in range(len(x)):
      if s < y[i]/x[i]**n:
          s = y[i]/x[i]**n
    return s

# %%
n = int(input())
m = int(input())
x = array.array('f')
y = array.array('f')
for i in range(n//2,n):
    if is_prime(i):
      x.append(i)
      y.append(period(i,m)/)



print(x)
print(y)
print('period(p)/p^',m-1,' ~ ', max(x,y,m-1))

plt.plot(x,y)
#plt.ylabel(y)
plt.show()

# %%
 n = int(input())
while n > 0:
  period(n)
  n = int(input())

# %%
n = int(input())
while n > 0:
    print('period of n is',period(n))
    n = int(input())

# %%
def fib3_period(n):
  arr = np.zeros((n**3,3))
  arr[0][0]=0
  arr[0][1]=0
  arr[0][2]=1
  arr[1][0]=0
  arr[1][1]=1
  arr[1][2]=1
  arr[2][0]=1
  arr[2][1]=1
  arr[2][2]=2
  s = 3
  #print(arr[0],arr[1], arr[2],sep='\n')
  while not( arr[s-1][0] == arr[0][0] and arr[s-1][1] == arr[0][1] and arr[s-1][2] == arr[0][2]):
    arr[s][0] = arr[s-1][1]
    arr[s][1] = arr[s-1][2]
    arr[s][2] = (arr[s-1][0] + arr[s-1][1] + arr[s-1][2])%n
   #print(arr[s])
    s += 1
  #print(arr,sep='\n')
  #print(s - 1)
  return s - 1



def square_max(x,y):
    s = 0
    for i in range(len(x)):
      if s < y[i]/x[i]:
          s = y[i]/x[i]**2
    return s

# %%
n = int(input())
x = array.array('f')
y = array.array('f')
for i in range(n//5,n):
    if is_prime(i):
      x.append(i)
      y.append(fib3_period(i)/i)



#print(x)
#print(y)
print('fib3_period(p)/p^2 ~ ', max(x,y))

plt.plot(x,y)
#plt.ylabel(y)
plt.show()
# Out:
# 100
# fib3_period(p)/p^2 ~  array('f', [24.04347801208496, 4.8275861740112305, 10.677419662475586, 12.675675392150879, 13.658536911010742, 7.162790775299072, 0.978723406791687, 0.9811320900917053, 60.01694869995117, 30.491804122924805, 22.671642303466797, 72.01408386230469, 72.98629760742188, 39.49367141723633, 3.457831382751465, 90.01123809814453, 32.67010498046875])

# %%
print(fib3_period(3),fib3_period(4),fib3_period(12))
# Out:
# 13 8 104
